# %% [markdown]
# # Homework 1

# %%
import pandas as pd
import numpy as np
import pathlib

# %%
DATA_PATH = pathlib.Path.cwd().parents[2].joinpath('data')
DATA_PATH
# Out:
# WindowsPath('c:/Users/Admin/desktop/machine-learning-zoomcamp/cohorts/2026/data')

# %% [markdown]
# ## Questions

# %% [markdown]
# ### Q1. Pandas version
#
# What version of Pandas did you install?

# %%
pd.__version__
# Out:
# '3.0.6'

# %% [markdown]
# ## Q2. Records count
#
# How many records are in the dataset?
#
# - 5000
# - 9000
# - **<ins>10000</ins>**
# - 15000

# %%
df = pd.read_csv(DATA_PATH.joinpath('car_fuel_efficiency_2026.csv'))
df.shape[0]
# Out:
# 10000

# %% [markdown]
# ## Q3. Fuel types
#
# How many fuel types are presented in the dataset?
#
# - 1
# - 2
# - **<ins>3</ins>**
# - 4

# %%
df['fuel_type'].unique()
# Out:
# <StringArray>
# ['Gasoline', 'Diesel', 'Hybrid']
# Length: 3, dtype: str

# %% [markdown]
# ## Q4. Missing values
#
# How many columns in the dataset have missing values?
#
# - 0
# - 1
# - **<ins>2</ins>**
# - 3
# - 4

# %%
len(df.columns[df.isna().any() == True])
# Out:
# 2

# %% [markdown]
# ## Q5. Max fuel efficiency
#
# What's the maximum fuel efficiency of cars from Asia?
#
# - 21.2
# - 31.2
# - **<ins>41.2</ins>**
# - 51.2

# %%
float(df[df['origin'] == "Asia"].fuel_efficiency_mpg.max())
# Out:
# 41.2

# %% [markdown]
# ## Q6. Median value of horsepower
#
# 1. Find the median value of the `horsepower` column in the dataset.
# 2. Next, calculate the most frequent value of the same `horsepower` column.
# 3. Use the `fillna` method to fill the missing values in the `horsepower` column with the most frequent value from the previous step.
# 4. Now, calculate the median value of `horsepower` once again.
#
# Has it changed?
#
#
# - Yes, it increased
# - **<ins>Yes, it decreased</ins>**
# - No

# %%
prev_horsepower_median = df.horsepower.median()
float(prev_horsepower_median)
# Out:
# 254.0

# %%
most_frequent_horsepower = df.horsepower.value_counts(ascending=False).index[0]
float(most_frequent_horsepower)
# Out:
# 252.0

# %%
df['horsepower'] = df.horsepower.fillna(most_frequent_horsepower)
curr_horsepower_median = df.horsepower.median()
float(curr_horsepower_median)
# Out:
# 252.0

# %% [markdown]
# ## Q7. Sum of weights
#
# 1. Select all the cars from Asia
# 2. Select only columns `vehicle_weight` and `model_year`
# 3. Select the first 7 values
# 4. Get the underlying NumPy array. Let's call it `X`.
# 5. Compute matrix-matrix multiplication between the transpose of `X` and `X`. To get the transpose, use `X.T`. Let's call the result `XTX`.
# 6. Invert `XTX`.
# 7. Create an array `y` with values `[1100, 1300, 800, 900, 1000, 1100, 1200]`.
# 8. Multiply the inverse of `XTX` with the transpose of `X`, and then multiply the result by `y`. Call the result `w`.
# 9. What's the sum of all the elements of the result?
#
# > **Note**: You just implemented linear regression. We'll talk about it in the next lesson.
#
# - 0.0369
# - **<ins>0.369</ins>**
# - 3.69
# - 36.9

# %%
df_cars = df[df['origin'] == "Asia"][['vehicle_weight', 'model_year']]

# %%
X = df_cars[:7].values
XTX = X.T.dot(X)
y = np.array([1100, 1300, 800, 900, 1000, 1100, 1200])
w = np.linalg.inv(XTX).dot(X.T).dot(y)
round(float(sum(w)), 4)
# Out:
# 0.3692
